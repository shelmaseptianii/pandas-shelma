# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.4

# %%
pd.DataFrame({'col1':[1, 2, 3, 4], 
              'col2':[5, 6, 7, 8]})
# Out:
#    col1  col2
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     8

# %%
n_rows = 5
n_cols = 3

arr = np.random.randint(1, 20, size=(n_rows, n_cols))
arr
# Out:
# array([[16, 19, 17],
#        [ 3,  4, 17],
#        [ 5, 17, 17],
#        [ 4, 15, 19],
#        [16,  4,  2]], dtype=int32)

# %%
pd.DataFrame(arr, columns=tuple('ABC'))
# Out:
#     A   B   C
# 0  16  19  17
# 1   3   4  17
# 2   5  17  17
# 3   4  15  19
# 4  16   4   2

# %%
n_rows = 30 
n_cols = 4 
columns = list('ABCD')

data = np.random.randn(n_rows, n_cols)

df = pd.DataFrame(data, columns=columns)

print(df.head())
# Out:
#           A         B         C         D
# 0  0.900163 -0.605984 -1.252961 -1.003656
# 1 -1.087172 -2.300538  1.208553 -0.458837
# 2 -0.722852 -0.225062 -0.085963  1.238595
# 3 -0.724351  0.458536 -0.305634 -1.674202
# 4 -0.526651  0.817429  1.813270 -1.633278

# %%
n_rows = 5 

data = {
    'A': np.random.randn(n_rows),                 
    'B': np.arange(1, n_rows + 1),                
    'C': pd.date_range('2024-01-01', periods=n_rows), 
    'D': ['foo', 'bar', 'baz', 'qux', 'quux']    
}

df = pd.DataFrame(data)

print(df.head())
# Out:
#           A  B          C     D
# 0  2.361642  1 2024-01-01   foo
# 1  0.109548  2 2024-01-02   bar
# 2  0.008640  3 2024-01-03   baz
# 3  1.465687  4 2024-01-04   qux
# 4 -0.691313  5 2024-01-05  quux

# %%
n_rows = 30  
n_cols = 4   
columns = list('ABCD')  

time_index = pd.date_range(start='2024-01-01', periods=n_rows, freq='D')  

df = pd.DataFrame(np.random.randn(n_rows, n_cols), index=time_index, columns=columns)

print(df.head())
# Out:
#                    A         B         C         D
# 2024-01-01  0.407750 -0.111616  0.819844  3.000689
# 2024-01-02 -0.615174 -0.230494 -0.925205  0.178500
# 2024-01-03 -0.562717  0.993765  0.227310 -1.795457
# 2024-01-04 -0.244392  0.995633 -0.151087 -0.069578
# 2024-01-05 -0.776079 -0.152799 -0.327723 -1.671174

# %%
n_rows = 5
n_cols = 4

data = np.random.randn(n_rows, n_cols)

df = pd.DataFrame(data, columns=list('ABCD'))

df.iloc[0, 1] = np.nan
df.iloc[2, 3] = np.nan
df.iloc[4, 0] = np.nan

print(df.head())
# Out:
#           A         B         C         D
# 0  0.245852       NaN  0.303170 -0.924219
# 1 -0.558392 -0.884677 -0.961906  0.588154
# 2 -1.875033 -0.231270 -1.230701       NaN
# 3  1.073257 -0.464819  2.739833  0.096850
# 4       NaN -0.082833  0.185596  0.905549
